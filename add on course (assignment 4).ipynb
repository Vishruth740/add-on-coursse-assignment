# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot([10, 20, 30], [20, 40, 10], linewidth=3)
ax.plot([10, 20, 30], [40,10,30], linewidth=3)
ax.set_xlim(10,35)
plt.show()
